# %%
import os
import random
import torch
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import mixed_precision as mp
from ultralytics import YOLO
from roboflow import Roboflow
from PIL import Image
from datetime import datetime
from dotenv import load_dotenv
from shutil import copy2

# %%
# use gpu if available
physical_devices = tf.config.list_physical_devices('GPU')
print("Physical devices:", physical_devices)
if physical_devices:
    print("GPU available, enabling mixed precision training")
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    policy = mp.Policy('mixed_float16')
    mp.set_global_policy(policy)
else:
    print("GPU not available, using CPU")

print("PyTorch CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

load_dotenv()
# Out:
# Physical devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU available, enabling mixed precision training
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060, compute capability 8.6
# PyTorch CUDA available: True
# NVIDIA GeForce RTX 3060
# True

# %%
def download_data(Roboflow, workspace_name, project_name, version, folderpath='datasets/player_tracking'):
    rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
    project1 = rf.workspace(workspace_name).project(project_name)
    version = project1.version(version)
    dataset = version.download("yolov11", location=folderpath)
    return dataset

def train_model(YOLO, tf, folderpath='datasets/player_tracking'):
    model = YOLO('yolo11n.pt')
    print(model)
    model.info()
    train_results = model.train(
        data=f"{folderpath}/data.yaml",
        epochs=150,
        imgsz=640,
        batch=16,
        device=0 if tf.config.list_physical_devices('GPU') else 'cpu',
        workers=4,
        optimizer='Adam',
        lr0=0.01,
        lrf=0.01,
        patience=20,
        project="runs/detect/train",
        name="yolov11-player-fixed",
        save=True,
        save_period=10,
        exist_ok=True,
        verbose=True,
        plots=True,
        val=True,
    )
    return model, train_results

def evaluate_model(model):
    metrics = model.val()
    return metrics

def run_inference(model, image_path):
    results = model(image_path)
    results[0].show()
    return results

def export_model(model):
    path = model.export(format="onnx")
    return path

# %%
# SKIP IF TRAINING/DATASETS/PLAYER_TRACKING ALREADY EXISTS

def download_roboflow_datasets(rf, datasets, base_folder):
    download_paths = []
    for ds in datasets:
        print(f"Downloading {ds['workspace']}/{ds['project']} version {ds['version']}...")
        workspace = rf.workspace(ds['workspace'])
        project = workspace.project(ds['project'])
        version = project.version(ds['version'])
        out_path = os.path.join(base_folder, f"{ds['project']}_v{ds['version']}")
        dataset = version.download('yolov11', location=out_path)
        print(f"Downloaded to: {dataset.location}")
        download_paths.append(dataset.location)
    return download_paths

rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
dataset_folderpath = "datasets/player_tracking"
merge_datasets = [
    {"workspace": "volley-pjhnb", "project": "volleyball-q7cun", "version": 3},
    {"workspace": "volleyball-9ape8", "project": "volleyball-g4zfi", "version": 2},
    {"workspace": "david-paulinus-54fnl", "project": "tracking-volleyball-players", "version": 6},
]
download_paths = download_roboflow_datasets(rf, merge_datasets, dataset_folderpath)

# %%
dataset_folderpath = "datasets/fixed_player_tracking"
# consolidated the above 3 datasets into one
# https://app.roboflow.com/daniel-88d0p/volleyball-players-wgaid/1
fixed_dataset = {"workspace": "daniel-88d0p", "project": "volleyball-players-wgaid", "version": 1}
dataset = download_data(Roboflow, workspace_name=fixed_dataset["workspace"], project_name=fixed_dataset["project"], version=fixed_dataset["version"], folderpath=dataset_folderpath)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# Downloading Dataset Version Zip in datasets/fixed_player_tracking to yolov11:: 100%|██████████| 168247/168247 [00:06<00:00, 27485.43it/s]
# Extracting Dataset Version Zip to datasets/fixed_player_tracking in yolov11:: 100%|██████████| 7648/7648 [00:05<00:00, 1505.49it/s]

# %%
model, train_results = train_model(YOLO, tf, folderpath='datasets/fixed_player_tracking')
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(8, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): C2PSA(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#         )
#       )
#       (11): Upsample(scale_factor=2.0, mode='nearest')
#       (12): Concat()
#       (13): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (14): Upsample(scale_factor=2.0, mode='nearest')
#       (15): Concat()
#       (16): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (17): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (18): Concat()
#       (19): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (20): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (21): Concat()
#       (22): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (23): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )
# YOLO11n summary: 181 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# Ultralytics 8.3.233  Python-3.10.11 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=datasets/fixed_player_tracking/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=150, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov11-player-fixed, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect/train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 593.0125.1 MB/s, size: 41.1 KB)
# train: Scanning D:\Coding\tobio\training\datasets\fixed_player_tracking\train\labels... 2703 images, 23 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2703/2703 2.9Kit/s 0.9s0.0s
# train: New cache created: D:\Coding\tobio\training\datasets\fixed_player_tracking\train\labels.cache
# WARNING Box and segment counts should be equal, but got len(segments) = 13, len(boxes) = 22579. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.10.0 ms, read: 278.976.6 MB/s, size: 49.1 KB)
# val: Scanning D:\Coding\tobio\training\datasets\fixed_player_tracking\valid\labels... 738 images, 9 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 738/738 2.7Kit/s 0.3s0.1ss
# val: New cache created: D:\Coding\tobio\training\datasets\fixed_player_tracking\valid\labels.cache
# Plotting labels to D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed\labels.jpg...
# optimizer: Adam(lr=0.01, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      2.41G       1.63       1.23      1.238        208        640: 100% ━━━━━━━━━━━━ 169/169 4.8it/s 34.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.1it/s 4.7s0.2s
#                    all        738       6275      0.757      0.738      0.783       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      2.41G      1.576     0.9896      1.226        259        640: 100% ━━━━━━━━━━━━ 169/169 7.0it/s 24.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 7.7it/s 3.1s0.1s
#                    all        738       6275      0.668      0.554      0.599      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      2.41G      1.553     0.9604      1.216        271        640: 100% ━━━━━━━━━━━━ 169/169 7.1it/s 23.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 7.6it/s 3.2s0.1s
#                    all        738       6275      0.799      0.756      0.816      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      2.41G      1.498     0.9037      1.195        253        640: 100% ━━━━━━━━━━━━ 169/169 7.2it/s 23.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.0it/s 3.0s0.1s
#                    all        738       6275      0.869      0.829      0.895      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      2.41G       1.46     0.8635      1.178        195        640: 100% ━━━━━━━━━━━━ 169/169 7.3it/s 23.2s0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 9.0it/s 2.7s0.1s
#                    all        738       6275      0.876      0.852      0.914      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150      2.41G       1.42     0.8212      1.148        230        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.8it/s 2.7s0.1s
#                    all        738       6275       0.86      0.824      0.888      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      2.41G      1.403     0.8221      1.145        213        640: 100% ━━━━━━━━━━━━ 169/169 7.8it/s 21.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.8it/s 2.7s0.1s
#                    all        738       6275      0.892       0.81      0.901      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/150      2.41G      1.393     0.7976      1.136        258        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 9.0it/s 2.7s0.1s
#                    all        738       6275      0.877      0.822      0.901      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150      2.41G      1.381     0.7919      1.127        199        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 21.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 9.1it/s 2.6s0.1s
#                    all        738       6275      0.879      0.879      0.926      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150      2.41G       1.37     0.7709      1.126        234        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.1it/s 2.9s0.1s
#                    all        738       6275      0.916      0.858      0.933      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150      2.41G      1.361     0.7623      1.127        234        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 9.0it/s 2.7s0.1s
#                    all        738       6275      0.906      0.838      0.929      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150      2.41G      1.349     0.7481      1.115        162        640: 100% ━━━━━━━━━━━━ 169/169 7.6it/s 22.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.6it/s 2.8s0.1s
#                    all        738       6275      0.886      0.865      0.926      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150      2.41G      1.345     0.7439      1.112        175        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.8it/s 2.7s0.1s
#                    all        738       6275      0.902      0.868      0.924      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      2.41G      1.341      0.747      1.115        176        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.9it/s 2.7s0.1s
#                    all        738       6275      0.858      0.832      0.901      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150      2.41G       1.33     0.7323      1.105        264        640: 100% ━━━━━━━━━━━━ 169/169 7.6it/s 22.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.2it/s 2.9s0.1s
#                    all        738       6275      0.886      0.845      0.919      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150      2.41G      1.327     0.7327      1.109        207        640: 100% ━━━━━━━━━━━━ 169/169 7.6it/s 22.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.7it/s 2.8s0.1s
#                    all        738       6275      0.896       0.85      0.924      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/150      2.41G      1.329     0.7332      1.109        195        640: 100% ━━━━━━━━━━━━ 169/169 7.6it/s 22.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.5it/s 2.8s0.1s
#                    all        738       6275      0.869      0.869      0.914      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/150      2.41G      1.304     0.7112      1.096        220        640: 100% ━━━━━━━━━━━━ 169/169 7.7it/s 22.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8.6it/s 2.8s0.1s
#                    all        738       6275      0.919      0.886      0.947      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/150      2.41G      1.306     0.7133      1.095        221        640: 100% ━━━━━━━━━━━━ 169/169 7.6it/s 22.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 8
0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 7.2it/s 3.3s0.1s
#                    all        738       6275       0.94      0.933      0.972      0.683
#
# 150 epochs completed in 1.051 hours.
# Optimizer stripped from D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed\weights\last.pt, 5.5MB
# Optimizer stripped from D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed\weights\best.pt, 5.5MB
#
# Validating D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed\weights\best.pt...
# Ultralytics 8.3.233  Python-3.10.11 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 24/24 5.3it/s 4.6s0.1s
#                    all        738       6275      0.947      0.929      0.973      0.685
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to D:\Coding\tobio\training\runs\detect\train\yolov11-player-fixed

# %%
metrics = evaluate_model(model)
# results = run_inference(model, "path/to/image.jpg")
onnx_path = export_model(model)
# Out:
# Ultralytics 8.3.233  Python-3.10.11 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# val: Fast image access  (ping: 0.10.0 ms, read: 114.6235.0 MB/s, size: 55.1 KB)
# val: Scanning D:\Coding\tobio\training\datasets\player_tracking\players\valid\labels.cache... 738 images, 7 backgrounds, 333 corrupt: 100% ━━━━━━━━━━━━ 738/738  0.0s
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1012_jpeg.rf.29fdb009012a109e9ddbfc78bfd10e9d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1044_jpeg.rf.6403c87c410ffa2e07a2ceebfb372dbb.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1045_jpeg.rf.42623a0887d02f569e9ba41e0e568b8a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1050_jpeg.rf.8f794c94263f6f34b70cc823392ad7ed.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1061_jpeg.rf.39546e415a23c77f46a22311a1fd93c4.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1073_jpeg.rf.5f9e7c5807300a3af93604843aa335aa.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1076_jpeg.rf.8e3ae518d0c79b0a14efdefe25838cb5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\110_jpeg.rf.8c2ee448f706839ca6e86d3217635dd7.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1146_jpeg.rf.693a40073d4ba480680cd27ed8370dd8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1153_jpeg.rf.ff80add5ba90a1f773ad648db9ef795b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1173_jpeg.rf.007831fd27d200de9b5d83cdd08bd4c8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1174_jpeg.rf.570ff9e5871f8504e9623f367c3d0757.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\117_jpeg.rf.15ad398c4b63dab1ba947effdcfebab8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1182_jpeg.rf.1808239504a9436710df4ca7fbaac44b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1253_jpeg.rf.13e35297973fb9ac62a639f6ac49e35e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\126_jpeg.rf.37e0a800e7a7dd828df7d9a0d3432dcc.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1306_jpeg.rf.c3c3b2163e8557e6e32beca14c0e9500.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1308_jpeg.rf.f34b236e816f79c234420cc2de0b5b67.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1328_jpeg.rf.da2c5b835dfd7d5bfa47d4e9cddba49f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\133_jpeg.rf.a16c7175f81e922d719513e4a80f4455.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1365_jpeg.rf.222fa08dd539c9a6632d3426b5657522.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1408_jpeg.rf.2b9c86a9d0a0d7c9ef316cc753988abe.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1422_jpeg.rf.48ae1b70549d1612f8b10316263c1d42.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1428_jpeg.rf.e15d6f6c3e810bfde7dcf7251f965866.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1441_jpeg.rf.2bbb47e24381c5ce254d9cf799c687e8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1456_jpeg.rf.2bcd5263490aef8e1a113dcbfb4f8f6d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1486_jpeg.rf.0554be30228589ee5402e37abe049298.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1494_jpeg.rf.fc57104ba4e6dd7fe137345d843996fb.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\149_jpeg.rf.b2bd4b7a539672c9731833240f4e70a5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1564_jpeg.rf.76cad0aa10dcbeef5c1028f1f114e8f4.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1566_jpeg.rf.2d1dff4a42b67ac0344ea622fef96bfa.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1590_jpeg.rf.244af3ce756a18230704f60684e1e66f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\1593_jpeg.rf.ac228695d30f9d2ee9417c0d4a257c76.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\
.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0441_jpg.rf.cd93ea9e57dde2c783a1f28dc3bbc3c8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0470_jpg.rf.efeafe2d6c8ae43288b0f2b9774e9312.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0475_jpg.rf.d629a6695bfb32016f26d1fe70306430.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0482_jpg.rf.cfaf0e138f21314f6725b09b851d7ed1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0487_jpg.rf.b76d1f13441ebebf9e07d03e299c88b5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0547_jpg.rf.060635e252c91127fca400f6ced9ed4f.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0569_jpg.rf.cd70a36ebcd3a7cbecc6a682e82899c9.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0580_jpg.rf.c9e4823d4d20ece19183cfc937c51c69.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\keyframe_0628_jpg.rf.fb6d594dec37c8a22c1e524180d2b31e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0023_jpg.rf.424f442c053f45b1144b3522d0dd52ef.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0043_jpg.rf.895990fb3cabb8c96f31994f41074fe1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0075_jpg.rf.fed57546ac8f7ebdfdda40078c1436d7.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0084_jpg.rf.c7b7e65de41174afe787e737a343c20b.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0086_jpg.rf.c316821204636344c42e95a48a0dc703.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0098_jpg.rf.d73202046421896cd5a7f08bb486a6a5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0117_jpg.rf.b6d443345c5c7aab8eb522d99b34477a.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0119_jpg.rf.cd1bdec2ffd225f669424539838809d7.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0138_jpg.rf.5db6aec4b583d82ac67335c18eba120c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0151_jpg.rf.7c94c784961c8ad39ce404213d1d3e57.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0153_jpg.rf.8a33c328d5a0118e9cd8a443c45aa86c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0155_jpg.rf.a246a9cc4ee69e5a3013af3595e41003.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0188_jpg.rf.96825b44b3ea642ea42994deb850acd3.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0189_jpg.rf.158a079fddc49cdda83171eec4de24f8.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0210_jpg.rf.59cb5b1d810220c5c387b067598568fe.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0215_jpg.rf.75d117d2c83f2d8598b8fd36299e19c0.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0218_jpg.rf.90e9ce0bd36c688d9858b3621219492d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0221_jpg.rf.b52aa68c7491b7335d1a22c325e8b720.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0236_jpg.rf.95895eb238b6464c7250d22a1aa6921e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0238_jpg.rf.791c3f7a2076d6be5332349060f0b039.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0239_jpg.rf.5c33b5caef1ec221cbdd6431a5b682ef.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0241_jpg.rf.2516aeb0b32962966df7c2f488f61cea.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0243_jpg.rf.527687cdf6522bcd65ab371a89203bf7.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0245_jpg.rf.5ce70aa2ff794672a3ccbe4e75c268de.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0250_jpg.rf.6649a7254c420d6651eacceeb3691150.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0252_jpg.rf.aa4ae2e6f187e4a33c2892bcfe2c637c.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# val: D:\Coding\tobio\training\datasets\player_tracking\players\valid\images\output_frame_0256_jpg.rf.db4ba27753c7e49337a82e251752abba.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 9.3it/s 2.8s<0.1s
#                    all        405       3933      0.969      0.958      0.986      0.707
# Speed: 1.2ms preprocess, 2.6ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to D:\Coding\tobio\runs\detect\val2
# Ultralytics 8.3.233  Python-3.10.11 torch-2.1.0+cu118 CPU (12th Gen Intel Core(TM) i7-12700)
#
# PyTorch: starting from 'D:\Coding\tobio\training\runs\detect\train\yolov11-player\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
# ERROR ONNX: export failure 0.2s: cannot import name 'builder' from 'google.protobuf.internal' (d:\Coding\tobio\.venv\lib\site-packages\google\protobuf\internal\__init__.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 metrics = evaluate_model(model)
#       2 # results = run_inference(model, "path/to/image.jpg")
# ----> 3 onnx_path = export_model(model)
#
# Cell In[3], line 44, in export_model(model)
#      43 def export_model(model):
# ---> 44     path = model.export(format="onnx")
#      45     return path
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\model.py:709, in Model.export(self, **kwargs)
#     701 custom = {
#     702     "imgsz": self.model.args["imgsz"],
#     703     "batch": 1,
#    (...)
#     706     "verbose": False,
#     707 }  # method defaults
#     708 args = {**self.overrides, **custom, **kwargs, "mode": "export"}  # highest priority args on the right
# --> 709 return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\exporter.py:538, in Exporter.__call__(self, model)
#     536     f[1] = self.export_engine(dla=dla)
#     537 if onnx:  # ONNX
# --> 538     f[2] = self.export_onnx()
#     539 if xml:  # OpenVINO
#     540     f[3] = self.export_openvino()
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\exporter.py:236, in try_export.<locals>.outer_func(*args, **kwargs)
#     234 except Exception as e:
#     235     LOGGER.error(f"{prefix} export failure {dt.t:.1f}s: {e}")
# --> 236     raise e
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\exporter.py:228, in try_export.<locals>.outer_func(*args, **kwargs)
#     226 try:
#     227     with Profile() as dt:
# --> 228         f = inner_func(*args, **kwargs)  # exported file/dir or tuple of (file/dir, *)
#     229     path = f if isinstance(f, (str, Path)) else f[0]
#     230     mb = file_size(path)
#
# File d:\Coding\tobio\.venv\lib\site-packages\ultralytics\engine\exporter.py:639, in Exporter.export_onnx(self, prefix)
#     637     requirements += ["onnxslim>=0.1.71", "onnxruntime" + ("-gpu" if torch.cuda.is_available() else "")]
#     638 check_requirements(requirements)
# --> 639 import onnx
#     641 opset = self.args.opset or best_onnx_opset(onnx, cuda="cuda" in self.device.type)
#     642 LOGGER.info(f"\n{prefix} starting export with onnx {onnx.__version__} opset {opset}...")
#
# File d:\Coding\tobio\.venv\lib\site-packages\onnx\__init__.py:84
#      82 from onnx import serialization
#      83 from onnx.onnx_cpp2py_export import ONNX_ML
# ---> 84 from onnx.external_data_helper import (
#      85     load_external_data_for_model,
#      86     write_external_data_tensors,
#      87     convert_model_to_external_data,
#      88 )
#      89 from onnx.onnx_pb import (
#      90     AttributeProto,
#      91     DeviceConfigurationProto,
#    (...)
#     124     Version,
#     125 )
#     126 from onnx.onnx_operators_pb import OperatorProto, OperatorSetProto
#
# File d:\Coding\tobio\.venv\lib\site-packages\onnx\external_data_helper.py:14
#      11 from typing import TYPE_CHECKING, Callable
#      13 import onnx.onnx_cpp2py_export.checker as c_checker
# ---> 14 from onnx.onnx_pb import (
#      15     AttributeProto,
#      16     FunctionProto,
#      17     GraphProto,
#      18     ModelProto,
#      19     TensorProto,
#      20 )
#      22 if TYPE_CHECKING:
#      23     from collections.abc import Iterable
#
# File d:\Coding\tobio\.venv\lib\site-packages\onnx\onnx_pb.py:4
#       1 # This file is generated by setup.py. DO NOT EDIT!
# ----> 4 from .onnx_ml_pb2 import *  # noqa
#
# File d:\Coding\tobio\.venv\lib\site-packages\onnx\onnx_ml_pb2.py:9
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#       8 from google.protobuf import symbol_database as _symbol_database
# ----> 9 from google.protobuf.internal import builder as _builder
#      10 # @@protoc_insertion_point(imports)
#      12 _sym_db = _symbol_database.Default()
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (d:\Coding\tobio\.venv\lib\site-packages\google\protobuf\internal\__init__.py)
